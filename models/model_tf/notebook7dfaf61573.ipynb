# %%
# !git clone -b dev https://github.com/SashaMogilevskii/model_compression
# Out:
# Cloning into 'model_compression'...
# remote: Enumerating objects: 103, done.
# remote: Counting objects: 100% (103/103), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 103 (delta 45), reused 75 (delta 24), pack-reused 0
# Receiving objects: 100% (103/103), 15.76 MiB | 17.85 MiB/s, done.
# Resolving deltas: 100% (45/45), done.

# %%
# !apt-get install unrar
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   unrar
# 0 upgraded, 1 newly installed, 0 to remove and 74 not upgraded.
# Need to get 145 kB of archives.
# After this operation, 339 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 unrar amd64 1:6.1.5-1 [145 kB]
# Fetched 145 kB in 1s (121 kB/s)
# Selecting previously unselected package unrar.
# (Reading database ... 113818 files and directories currently installed.)
# Preparing to unpack .../unrar_1%3a6.1.5-1_amd64.deb ...
# Unpacking unrar (1:6.1.5-1) ...
# Setting up unrar (1:6.1.5-1) ...
# update-alternatives: using /usr/bin/unrar-nonfree to provide /usr/bin/unrar (unrar) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/unrar.1.gz because associated file /usr/share/man/man1/unrar-nonfree.1.gz (of link group unrar) doesn't exist
# Processing triggers for man-db (2.10.2-1) ...

# %%
pip install python-box loguru gdown
# Out:
# Collecting python-box
#   Downloading python_box-7.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 45.4 MB/s eta 0:00:0000:0100:01
# Collecting loguru
#   Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 6.6 MB/s eta 0:00:00
# Collecting gdown
#   Downloading gdown-4.7.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from gdown) (3.12.2)
# Requirement already satisfied: requests[socks] in /opt/conda/lib/python3.10/site-packages (from gdown) (2.31.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from gdown) (4.66.1)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from gdown) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->gdown) (2.3.2.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (2023.7.22)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.7.1)
# Installing collected packages: python-box, loguru, gdown
# Successfully installed gdown-4.7.1 loguru-0.7.2 python-box-7.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow==2.14.0
# Out:
# Collecting tensorflow==2.14.0
#   Downloading tensorflow-2.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (489.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.8/489.8 MB 2.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.14.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.14.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.14.0) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.14.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.14.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.14.0) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.14.0) (16.0.0)
# Requirement already satisfied: ml-dtypes==0.2.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.14.0) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.14.0) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.14.0) (3.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.14.0) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.14.0) (3.20.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.14.0) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.14.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.14.0) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.14.0) (4.6.3)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.14.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.14.0) (0.32.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.14.0) (1.51.1)
# Collecting tensorboard<2.15,>=2.14 (from tensorflow==2.14.0)
#   Downloading tensorboard-2.14.1-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 78.4 MB/s eta 0:00:00:00:01
# Collecting tensorflow-estimator<2.15,>=2.14.0 (from tensorflow==2.14.0)
#   Downloading tensorflow_estimator-2.14.0-py2.py3-none-any.whl (440 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 kB 37.1 MB/s eta 0:00:00
# Collecting keras<2.15,>=2.14.0 (from tensorflow==2.14.0)
#   Downloading keras-2.14.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 70.2 MB/s eta 0:00:00
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow==2.14.0) (0.40.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0) (2.20.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0) (2.3.7)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow==2.14.0) (3.0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (4.9)
# Requirement already satisfied: urllib3<2.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (1.26.15)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (2.1.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (3.2.2)
# Installing collected packages: tensorflow-estimator, keras, tensorboard, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.12.0
#     Uninstalling tensorflow-estimator-2.12.0:
#       Successfully uninstalled tensorflow-estimator-2.12.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.12.0
#     Uninstalling keras-2.12.0:
#       Successfully uninstalled keras-2.12.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.12.3
#     Uninstalling tensorboard-2.12.3:
#       Successfully uninstalled tensorboard-2.12.3
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.12.0
#     Uninstalling tensorflow-2.12.0:
#       Successfully uninstalled tensorflow-2.12.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.4.0 requires tensorflow~=2.12.0, but you have tensorflow 2.14.0 which is incompatible.
# tensorflow-text 2.12.1 requires tensorflow<2.13,>=2.12.0; platform_machine != "arm64" or platform_system != "Darwin", but you have tensorflow 2.14.0 which is incompatible.
# Successfully installed keras-2.14.0 tensorboard-2.14.1 tensorflow-2.14.0 tensorflow-estimator-2.14.0
# Note: you may need to restart the kernel to use updated packages.

# %%
cd /kaggle/working/model_compression/data
# Out:
# /kaggle/working/model_compression/data

# %%
# !gdown --id "18gCWw8IkqbFr9X0TCBM5LCpsU11Ga6tc"
# Out:
# /opt/conda/lib/python3.10/site-packages/gdown/cli.py:126: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=18gCWw8IkqbFr9X0TCBM5LCpsU11Ga6tc
# From (redirected): https://drive.google.com/uc?id=18gCWw8IkqbFr9X0TCBM5LCpsU11Ga6tc&confirm=t&uuid=b3e52baf-1f7f-4f81-b636-bf0faa34aa93
# To: /kaggle/working/model_compression/data/data.rar
# 100%|██████████████████████████████████████| 6.41G/6.41G [06:00<00:00, 17.8MB/s]

# %%
# !unrar x data.rar
# Out:
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from data.rar
#
# Creating    data                                                      OK
# Creating    data/add_audio                                            OK
# Creating    data/add_audio/abethr1                                    OK
# Extracting  data/add_audio/abethr1/XC300826 - Bare-eyed Thrush - Turdus tephronotus.mp3     0  OK
# Extracting  data/add_audio/abethr1/XC300827 - Bare-eyed Thrush - Turdus tephronotus.mp3     0  OK
# Extracting  data/add_audio/abethr1/XC469066 - Bare-eyed Thrush - Turdus tephronotus.mp3     0  OK
# Extracting  data/add_audio/abethr1/XC510447 - Bare-eyed Thrush - Turdus tephronotus.mp3     0  OK
# Extracting  data/add_audio/abethr1/XC510448 - Bare-eyed Thrush - Turdus tephronotus.mp3     0  OK
# Extracting  data/add_audio/abethr1/XC510449 - Bare-eyed Thrush - Turdus tephronotus.mp3     0  OK
# Creating    data/add_audio/add_data_3                                 OK
# Creating    data/add_audio/add_data_3/abethr1                         OK
# Extracting  data/add_audio/add_data_3/abethr1/XC300826 - Bare-eyed Thrush - Turdus tephronotus.mp3     0  OK
# Extracting  data/add_audio/add_data_3/abethr1/XC300827 - Bare-eyed Thrush - Turdus tephronotus.mp3     0  OK
# Extracting  data/add_audio/add_data_3/abethr1/XC469066 - Bare-eyed Thrush - Turdus tephronotus.mp3     0  OK
# Extracting  data/add_audio/add_data_3/abethr1/XC510447 - Bare-eyed Thrush - Turdus tephronotus.mp3     0  OK
# Extracting  data/add_audio/add_data_3/abethr1/XC510448 - Bare-eyed Thrush - Turdus tephronotus.mp3     0  OK
# Extracting  data/add_audio/add_data_3/abethr1/XC510449 - Bare-eyed Thrush - Turdus tephronotus.mp3     0  OK
# Creating    data/add_audio/add_data_3/afbfly1                         OK
# Extracting  data/add_audio/add_data_3/afbfly1/XC425383 - African Blue Flycatcher - Elminia longicauda.mp3     0  OK
# Extracting  data/add_audio/add_data_3/afbfly1/XC425384 - African Blue Flycatcher - Elminia longicauda.mp3     0  OK
# Extracting  data/add_audio/add_data_3/afbfly1/XC48967 - African Blue Flycatcher - Elminia longicauda.mp3     0  OK
# Extracting  data/add_audio/add_data_3/afbfly1/XC719105 - African Blue Flycatcher - Elminia longicauda.mp3     0  OK
# Extracting  data/add_audio/add_data_3/afbfly1/XC719106 - African Blue Flycatcher - Elminia longicauda.mp3     0  OK
# Extracting  data/add_audio/add_data_3/afbfly1/XC739651 - African Blue Flycatcher - Elminia longicauda.mp3     0  OK
# Creating    data/add_audio/add_data_3/affeag1                         OK
# Extracting  data/add_audio/add_data_3/affeag1/105_110.mp3                0  OK
# Extracting  data/add_audio/add_data_3/affeag1/70_75.mp3                  0  OK
# Creating    data/add_audio/add_data_3/afgfly1                         OK
# Extracting  data/add_audio/add_data_3/afgfly1/XC278360 - African Grey Flycatcher - Melaenornis microrhynchus neumanni.mp3     0  OK
# Extracting  data/add_audio/add_data_3/afgfly1/XC300445 - African Grey Flycatcher - Melaenornis microrhynchus.mp3     0  OK
# Extracting  data/add_audio/add_data_3/afgfly1/XC300449 - African Grey Flycatcher - Melaenornis microrhynchus.mp3     0  OK
# Extracting  data/add_audio/add_data_3/afgfly1/XC300450 - African Grey Flycatcher - Melaenornis microrhynchus.mp3     0  OK
# Extracting  data/add_audio/add_data_3/afgfly1/XC33992 - African Grey Flycatcher - Melaenornis microrhynchus.mp3     0  OK
# Extracting  data/add_audio/add_data_3/afgfly1/XC449601 - African Grey Flycatcher - Melaenornis microrhynchus.mp3     0  OK
# Extracting  data/add_audio/add_data_3/afgfly1/XC449602 - African Grey Flycatcher - Melaenornis microrhynchus.mp3     0  OK
# Extracting  data/add_audio/add_data_3/afgfly1/XC510235 - African Grey Flycatcher - Melaenornis microrhynchus.mp3     0  OK
# Extracting  data/add_audio/add_data_3/afgfly1/XC510236 - African Grey Flycatcher - Melaenornis microrhynchus.mp3     0  OK
# Extracting  data/add_audio/add_data_3/afgfly1/XC510237 - African Grey Flycatcher - Melaenornis microrhynchus.mp3     0  OK
# Extracting  data/add_audio/add_data_3/afgfly1/XC510238 - African Grey Flycatcher - Melaenornis microrhynchus.mp3     0  OK
# Extracting  data/add_audio/add_data_3/afgfly1/XC77338 - African Grey Flycatcher - Melaenornis microrhynchus.mp3     0  OK
# Creating    data/add_audio/add_data_3/afpkin1                         OK
# Extracting  data/add_audio/add_data_3/afpkin1/XC209957 - African Pygmy Kingfisher - Ispidina picta picta.mp3     0  OK
# Extracting  data/add_audio/add_data_3/afpkin1/XC290244 - African Pygmy Kingfisher - Ispidina picta.mp3     0  OK
# Extracting  data/add_audio/add_data_3/afpkin1/XC425176 - African Pygmy Kingfisher - Ispidina picta.mp3     0  OK
# Extracting  data/add_audio/add_data_3/afpkin1/XC476827 - African Pygmy Kingfisher - Ispidina picta picta(1).mp3     0  OK
# Extracting  data/add_audio/add_data_3/afpkin1/XC476827 - African Pygmy Kingfisher - Ispidina picta picta.mp3     0  OK
# Extracting  data/add_audio/add_data_3/afpkin1/XC510189 - African Pygmy Kingfisher - Ispidina picta.mp3     0  OK
# Extracting  data/add_audio/add_data_3/afpkin1/XC647178 - African Pygmy Kingfisher - Ispidina picta natalensis.mp3     0  OK
# Creating    data/add_audio/add_data_3/augbuz1                         OK
# Extracting  data/add_audio/add_data_3/augbuz1/xc429960-augur-buzzard-buteo-augur_iQJEuatd.mp3     0  OK
# Extracting  data/add_audio/add_data_3/augbuz1/XC430172 - Augur Buzzard - Buteo augur.mp3     0  OK
# Extracting  data/add_audio/add_data_3/augbuz1/XC430173 - Augur Buzzard - Buteo augur.mp3     0  OK
# Extracting  data/add_audio/add_data_3/augbuz1/XC449288 - Augur Buzzard - Buteo augur.mp3     0  OK
# Extracting  data/add_audio/add_data_3/augbuz1/XC449289 - Augur Buzzard - Buteo augur.mp3     0  OK
# Extracting  data/add_audio/add_data_3/augbuz1/XC64902 - Augur Buzzard - Buteo augur.mp3     0  OK
# Extracting  data/add_audio/add_data_3/augbuz1/XC66308 - Augur Buzzard - Buteo augur.mp3     0  OK
# Extracting  data/add_audio/add_data_3/augbuz1/XC88562 - Augur Buzzard - Buteo augur.mp3     0  OK
# Creating    data/add_audio/add_data_3/bawman1                         OK
# Extracting  data/add_audio/add_data_3/bawman1/XC276877 - Black-and-white Mannikin - Spermestes bicolor poensis.mp3     0  OK
# Extracting  data/add_audio/add_data_3/bawman1/XC413941 - Black-and-white Mannikin - Spermestes bicolor bicolor.mp3     0  OK
# Extracting  data/add_audio/add_data_3/bawman1/XC739779 - Black-and-white Mannikin - Spermestes bicolor.mp3     0  OK
# Extracting  data/add_audio/add_data_3/bawman1/XC99047 - Black-and-white Mannikin - Spermestes bicolor poensis.mp3     0  OK
# Creating    data/add_audio/add_data_3/blhher1                         OK
# Extracting  data/add_audio/add_data_3/blhher1/XC269275 - Black-headed Heron - Ardea melanocephala.mp3     0  OK
# Extracting  data/add_audio/add_data_3/blhher1/XC392308 - Black-headed Heron - Ardea melanocephala.mp3     0  OK
# Extracting  data/add_audio/add_data_3/blhher1/XC455447 - Black-headed Heron - Ardea melanocephala.mp3     0  OK
# Extracting  data/add_audio/add_data_3/blhher1/XC455448 - Black-headed Heron - Ardea melanocephala.mp3     0  OK
# Extracting  data/add_audio/add_data_3/blhher1/XC739412 - Black-headed Heron - Ardea melanocephala.mp3     0  OK
# Creating    data/add_audio/add_data_3/blksaw1                         OK
# Extracting  data/add_audio/add_data_3/blksaw1/XC210013 - Black Saw-wing - Psalidoprocne pristoptera.mp3     0  OK
# Extracting  data/add_audio/add_data_3/blksaw1/XC292874 - Black Saw-wing - Psalidoprocne pristoptera.mp3     0  OK
# Extracting  data/add_audio/add_data_3/blksaw1/XC366621 - Black Saw-wing - Psalidoprocne pristoptera orientalis.mp3     0  OK
# Extracting  data/add_audio/add_data_3/blksaw1/XC366622 - Black Saw-wing - Psalidoprocne pristoptera orientalis.mp3     0  OK
# Extracting  data/add_audio/add_data_3/blksaw1/XC392664 - Black Saw-wing - Psalidoprocne pristoptera.mp3     0  OK
# Extracting  data/add_audio/add_data_3/blksaw1/XC429893 - Black Saw-wing - Psalidoprocne pristoptera massaica.mp3     0  OK
# Extracting  data/add_audio/add_data_3/blksaw1/XC510370 - Black Saw-wing - Psalidoprocne pristoptera.mp3     0  OK
# Extracting  data/add_audio/add_data_3/blksaw1/XC739954 - Black Saw-wing - Psalidoprocne pristoptera.mp3     0  OK
# Extracting  data/add_audio/add_data_3/blksaw1/XC739955 - Black Saw-wing - Psalidoprocne pristoptera.mp3     0  OK
# Extracting  data/add_audio/add_data_3/blksaw1/XC739956 - Black Saw-wing - Psalidoprocne pristoptera.mp3     0  OK
# Extracting  data/add_audio/add_data_3/
# Extracting  data/add_audio/add_data_3/blwlap1/XC300864 - Black-winged Lapwing - Vanellus melanopterus.mp3     1  OK
# Extracting  data/add_audio/add_data_3/blwlap1/XC510465 - Black-winged Lapwing - Vanellus melanopterus.mp3     1  OK
# Extracting  data/add_audio/add_data_3/blwlap1/XC517498 - Black-winged Lapwing - Vanellus melanopterus minor.mp3     1  OK
# Extracting  data/add_audio/add_data_3/blwlap1/XC517499 - Black-winged Lapwing - Vanellus melanopterus minor.mp3     1  OK
# Extracting  data/add_audio/add_data_3/blwlap1/XC77370 - Black-winged Lapwing - Vanellus melanopterus.mp3     1  OK
# Creating    data/add_audio/add_data_3/brcale1                         OK
# Extracting  data/add_audio/add_data_3/brcale1/XC101157 - Brown-chested Alethe - Chamaetylas poliocephala.mp3     1  OK
# Extracting  data/add_audio/add_data_3/brcale1/XC453434 - Brown-chested Alethe - Chamaetylas poliocephala carruthersi.mp3     1  OK
# Extracting  data/add_audio/add_data_3/brcale1/XC739514 - Brown-chested Alethe - Chamaetylas poliocephala.mp3     1  OK
# Extracting  data/add_audio/add_data_3/brcale1/XC739516 - Brown-chested Alethe - Chamaetylas poliocephala.mp3     1  OK
# Extracting  data/add_audio/add_data_3/brcale1/XC739517 - Brown-chested Alethe - Chamaetylas poliocephala.mp3     1  OK
# Creating    data/add_audio/add_data_3/brcsta1                         OK
# Extracting  data/add_audio/add_data_3/brcsta1/XC101155 - Bristle-crowned Starling - Onychognathus salvadorii.mp3     1  OK
# Extracting  data/add_audio/add_data_3/brcsta1/XC300510 - Bristle-crowned Starling - Onychognathus salvadorii.mp3     1  OK
# Extracting  data/add_audio/add_data_3/brcsta1/XC305848 - Bristle-crowned Starling - Onychognathus salvadorii.mp3     1  OK
# Extracting  data/add_audio/add_data_3/brcsta1/XC771983 - Bristle-crowned Starling - Onychognathus salvadorii.mp3     1  OK
# Extracting  data/add_audio/add_data_3/brcsta1/XC796377 - Bristle-crowned Starling - Onychognathus salvadorii.mp3     1  OK
# Creating    data/add_audio/add_data_3/brcwea1                         OK
# Extracting  data/add_audio/add_data_3/brcwea1/XC234856 - Brown-capped Weaver - Ploceus insignis.mp3     1  OK
# Extracting  data/add_audio/add_data_3/brcwea1/XC450384 - Brown-capped Weaver - Ploceus insignis.mp3     1  OK
# Extracting  data/add_audio/add_data_3/brcwea1/XC450388 - Brown-capped Weaver - Ploceus insignis.mp3     1  OK
# Extracting  data/add_audio/add_data_3/brcwea1/XC739921 - Brown-capped Weaver - Ploceus insignis.mp3     1  OK
# Extracting  data/add_audio/add_data_3/brcwea1/XC739922 - Brown-capped Weaver - Ploceus insignis.mp3     1  OK
# Creating    data/add_audio/add_data_3/brrwhe3                         OK
# Extracting  data/add_audio/add_data_3/brrwhe3/XC450398 - Kikuyu White-eye - Zosterops kikuyuensis.mp3     1  OK
# Extracting  data/add_audio/add_data_3/brrwhe3/XC455646 - Kikuyu White-eye - Zosterops kikuyuensis.mp3     1  OK
# Extracting  data/add_audio/add_data_3/brrwhe3/XC455648 - Kikuyu White-eye - Zosterops kikuyuensis.mp3     1  OK
# Extracting  data/add_audio/add_data_3/brrwhe3/XC774762 - Kikuyu White-eye - Zosterops kikuyuensis.mp3     1  OK
# Extracting  data/add_audio/add_data_3/brrwhe3/XC774764 - Kikuyu White-eye - Zosterops kikuyuensis.mp3     1  OK
# Extracting  data/add_audio/add_data_3/brrwhe3/XC92935 - Kikuyu White-eye - Zosterops kikuyuensis.mp3     1  OK
# Extracting  data/add_audio/add_data_3/brrwhe3/XC93106 - Kikuyu White-eye - Zosterops kikuyuensis.mp3     1  OK
# Creating    data/add_audio/add_data_3/brtcha1                         OK
# Extracting  data/add_audio/add_data_3/brtcha1/XC276884 - Brown-tailed Rock Chat - Oenanthe scotocerca turkana.mp3     1  OK
# Extracting  data/add_audio/add_data_3/brtcha1/XC276886 - Brown-tailed Rock Chat - Oenanthe scotocerca turkana.mp3     1  OK
# Extracting  data/add_audio/add_data_3/brtcha1/XC276887 - Brown-tailed Rock Chat - Oenanthe scotocerca turkana.mp3     1  OK
# Extracting  data/add_audio/add_data_3/brtcha1/XC276889 - Brown-tailed Rock Chat - Oenanthe scotocerca turkana.mp3     1  OK
# Extracting  data/add_audio/add_data_3/brtcha1/XC451544 - Brown-tailed Rock Chat - Oenanthe scotocerca turkana.mp3     1  OK
# Extracting  data/add_audio/add_data_3/brtcha1/XC451545 - Brown-tailed Rock Chat - Oenanthe scotocerca turkana.mp3     1  OK
# Creating    data/add_audio/add_data_3/bubwar2                         OK
# Extracting  data/add_audio/add_data_3/bubwar2/XC277991 - Buff-bellied Warbler - Phyllolais pulchella.mp3     1  OK
# Extracting  data/add_audio/add_data_3/bubwar2/XC300542 - Buff-bellied Warbler - Phyllolais pulchella.mp3     1  OK
# Extracting  data/add_audio/add_data_3/bubwar2/XC300543 - Buff-bellied Warbler - Phyllolais pulchella.mp3     1  OK
# Extracting  data/add_audio/add_data_3/bubwar2/XC300544 - Buff-bellied Warbler - Phyllolais pulchella.mp3     1  OK
# Extracting  data/add_audio/add_data_3/bubwar2/XC397809 - Buff-bellied Warbler - Phyllolais pulchella.mp3     1  OK
# Extracting  data/add_audio/add_data_3/bubwar2/XC398907 - Buff-bellied Warbler - Phyllolais pulchella.mp3     1  OK
# Extracting  data/add_audio/add_data_3/bubwar2/XC451772 - Buff-bellied Warbler - Phyllolais pulchella.mp3     1  OK
# Extracting  data/add_audio/add_data_3/bubwar2/XC510321 - Buff-bellied Warbler - Phyllolais pulchella.mp3     1  OK
# Extracting  data/add_audio/add_data_3/bubwar2/XC510323 - Buff-bellied Warbler - Phyllolais pulchella.mp3     1  OK
# Creating    data/add_audio/add_data_3/ccbeat1                         OK
# Extracting  data/add_audio/add_data_3/ccbeat1/XC430144 - Cinnamon-chested Bee-eater - Merops oreobates.mp3     1  OK
# Extracting  data/add_audio/add_data_3/ccbeat1/XC430145 - Cinnamon-chested Bee-eater - Merops oreobates.mp3     1  OK
# Extracting  data/add_audio/add_data_3/ccbeat1/XC430146 - Cinnamon-chested Bee-eater - Merops oreobates.mp3     1  OK
# Extracting  data/add_audio/add_data_3/ccbeat1/XC430147 - Cinnamon-chested Bee-eater - Merops oreobates.mp3     1  OK
# Extracting  data/add_audio/add_data_3/ccbeat1/XC449603 - Cinnamon-chested Bee-eater - Merops oreobates.mp3     1  OK
# Extracting  data/add_audio/add_data_3/ccbeat1/XC510252 - Cinnamon-chested Bee-eater - Merops oreobates.mp3     1  OK
# Extracting  data/add_audio/add_data_3/ccbeat1/XC94931 - Cinnamon-chested Bee-eater - Merops oreobates.mp3     1  OK
# Extracting  data/add_audio/add_data_3/ccbeat1/XC98681 - Cinnamon-chested Bee-eater - Merops oreobates oreobates.mp3     1  OK
# Creating    data/add_audio/add_data_3/chespa1                         OK
# Extracting  data/add_audio/add_data_3/chespa1/XC305858 - Chestnut Sparrow - Passer eminibey.mp3     1  OK
# Extracting  data/add_audio/add_data_3/chespa1/XC449613 - Chestnut Sparrow - Passer eminibey.mp3     1  OK
# Extracting  data/add_audio/add_data_3/chespa1/XC510295 - Chestnut Sparrow - Passer eminibey.mp3     1  OK
# Extracting  data/add_audio/add_data_3/chespa1/XC510296 - Chestnut Sparrow - Passer eminibey.mp3     1  OK
# Extracting  data/add_audio/add_data_3/chespa1/XC635368 - Chestnut Sparrow - Passer eminibey.mp3     1  OK
# Creating    data/add_audio/add_data_3/chewea1                         OK
# Extracting  data/add_audio/add_data_3/chewea1/XC326626 - Chestnut Weaver - Ploceus rubiginosus.mp3     1  OK
# Extracting  data/add_audio/add_data_3/chewea1/XC510348 - Chestnut Weaver - Ploceus rubiginosus.mp3     1  OK
# Extracting  data/add_audio/add_data_3/chewea1/XC510350 - Chestnut Weaver - Ploceus rubiginosus.mp3     1  OK
# Extracting  data/add_audio/add_data_3/chewea1/XC510351 - Chestnut Weaver - Ploceus rubiginosus.mp3     1  OK
# Creating    data/add_audio/add_data_3/crefra2                         OK
# Extracting  data/add_audio/add_data_3/crefra2/XC113618 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC129683 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC131663 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC185643 - Crested Francolin - Ortygornis sephaena rovuma.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC196087 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC209369 - Crested Francolin - Ortygornis sephaena zambesiae.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC210091 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC210092 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC210299 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC210300 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC237750 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC280240 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC280241 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC280242 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC280243 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC280244 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC300240 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC300241 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC300242 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC304235 - Crested Francolin - Ortygornis sephaena rovuma.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC305932 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC305933 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC307197 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC349208 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC370075 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC373663 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC373983 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC39398 - Crested Francolin - Ortygornis sephaena grantii.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC418733 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC429642 - Crested Francolin - Ortygornis sephaena grantii.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC434437 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC439377 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC453768 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC462084 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC473975 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC48355 - Crested Francolin - Ortygornis sephaena.mp3     1  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC510130 - Crested Francolin - Ortygornis sephaena.mp3     2  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC510131 - Crested Francolin - Ortygornis sephaena.mp3     2  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC510132 - Crested Francolin - Ortygornis sephaena.mp3     2  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC516136 - Crested Francolin - Ortygornis sephaena sephaena.mp3     2  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC528541 - Crested Francolin - Ortygornis sephaena.mp3     2  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC530056 - Crested Francolin - Ortygornis sephaena.mp3     2  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC537452 - Crested Francolin - Ortygornis sephaena grantii.mp3     2  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC596329 - Crested Francolin - Ortygornis sephaena.mp3     2  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC61607 - Crested Francolin - Ortygornis sephaena sephaena.mp3     2  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC93917 - Crested Francolin - Ortygornis sephaena.mp3     2  OK
# Extracting  data/add_audio/add_data_3/crefra2/XC94705 - Crested Francolin - Ortygornis sephaena.mp3     2  OK
# Creating    data/add_audio/add_data_3/darbar1                         OK
# Extracting  data/add_audio/add_data_3/darbar1/475_485.mp3                2  OK
# Creating    data/add_audio/add_data_3/darter3                         OK
# Extracting  data/add_audio/add_data_3/darter3/XC53995 - African Darter - Anhinga rufa.mp3     2  OK
# Extracting  data/add_audio/add_data_3/darter3/XC615903 - African Darter - Anhinga rufa rufa.mp3     2  OK
# Extracting  data/add_audio/add_data_3/darter3/XC615905 - African Darter - Anhinga rufa rufa.mp3     2  OK
# Creating    data/add_audio/add_data_3/dotbar1                         OK
# Extracting  data/add_audio/add_data_3/dotbar1/XC300438 - Double-toothed Barbet - Lybius bidentatus.mp3     2  OK
# Extracting  data/add_audio/add_data_3/dotbar1/XC300439 - Double-toothed Barbet - Lybius bidentatus.mp3     2  OK
# Extracting  data/add_audio/add_data_3/dotbar1/XC433610 - Double-toothed Barbet - Lybius bidentatus.mp3     2  OK
# Extracting  data/add_audio/add_data_3/dotbar1/XC455535 - Double-toothed Barbet - Lybius bidentatus aequatorialis.mp3     2  OK
# Creating    data/add_audio/add_data_3/dutdov1                         OK
# Extracting  data/add_audio/add_data_3/dutdov1/XC196107 - Dusky Turtle Dove - Streptopelia lugens.mp3     2  OK
# Extracting  data/add_audio/add_data_3/dutdov1/XC276761 - Dusky Turtle Dove - Streptopelia lugens.mp3     2  OK
# Extracting  data/add_audio/add_data_3/dutdov1/XC300707 - Dusky Turtle Dove - Streptopelia lugens.mp3     2  OK
# Extracting  data/add_audio/add_data_3/dutdov1/XC410332 - Dusky Turtle Dove - Streptopelia lugens.mp3     2  OK
# Extracting  data/add_audio/add_data_3/dutdov1/XC537903 - Dusky Turtle Dove - Streptopelia lugens.mp3     2  OK
# Creating    data/add_audio/add_data_3/easmog1                         OK
# Extracting  data/add_audio/add_data_3/easmog1/XC739416 - Olive-breasted Greenbul - Arizelocichla kikuyuensis.mp3     2  OK
# Extracting  data/add_audio/add_data_3/easmog1/XC785108 - Olive-breasted Greenbul - Arizelocichla kikuyuensis.wav     2  OK
# Creating    data/add_audio/add_data_3/equaka1                         OK
# Extracting  data/add_audio/add_data_3/equaka1/XC452027 - Equatorial Akalat - Sheppardia aequatorialis aequatorialis.mp3     2  OK
# Extracting  data/add_audio/add_data_3/equaka1/XC452028 - Equatorial Akalat - Sheppardia aequatorialis aequatorialis.mp3     2  OK
# Extracting  data/add_audio/add_data_3/equaka1/XC739998 - Equatorial Akalat - Sheppardia aequatorialis.mp3     2  OK
# Extracting  data/add_audio/add_data_3/equaka1/XC740000 - Equatorial Akalat - Sheppardia aequatorialis.mp3     2  OK
# Creating    data/add_audio/add_data_3/fislov1                         OK
# Extracting  data/add_audio/add_data_3/fislov1/XC107059 - Fischer's Lovebird - Agapornis fischeri.mp3     2  OK
# Extracting  data/add_audio/add_data_3/fislov1/XC429937 - Fischer's Lovebird - Agapornis fischeri.mp3     2  OK
# Extracting  data/add_audio/add_data_3/fislov1/XC429938 - Fischer's Lovebird - Agapornis fischeri.mp3     2  OK
# Extracting  data/add_audio/add_data_3/fislov1/XC429941 - Fischer's Lovebird - Agapornis fischeri.mp3     2  OK
# Extracting  data/add_audio/add_data_3/fislov1/XC62922 - Fischer's Lovebird - Agapornis fischeri.mp3     2  OK
# Extracting  data/add_audio/add_data_3/fislov1/XC67449 - Fischer's Lovebird - Agapornis fischeri.mp3     2  OK
# Extracting  data/add_audio/add_data_3/fislov1/XC773364 - Fischer's Lovebird - Agapornis fischeri.wav     2  OK
# Extracting  data/add_audio/add_data_3/fislov1/XC798772 - Fischer's Lovebird - Agapornis fischeri.mp3     2  OK
# Creating    data/add_audio/add_data_3/gnhsun1                         OK
# Extracting  data/add_audio/add_data_3/gnhsun1/XC101171 - Green-headed Sunbird - Cyanomitra verticalis.mp3     2  OK
# Extracting  data/add_audio/add_data_3/gnhsun1/XC110345 - Green-headed Sunbird - Cyanomitra verticalis bohndorffi.mp3     2  OK
# Extracting  data/add_audio/add_data_3/gnhsun1/XC311909 - Green-headed Sunbird - Cyanomitra verticalis viridisplendens.mp3     2  OK
# Extracting  data/add_audio/add_data_3/gnhsun1/XC451954 - Green-headed Sunbird - Cyanomitra verticalis viridisplendens.mp3     2  OK
# Extracting  data/add_audio/add_data_3/gnhsun1/XC62734 - Green-headed Sunbird - Cyanomitra verticalis.mp3     2  OK
# Extracting  data/add_audio/add_data_3/gnhsun1/XC702996 - Green-headed Sunbird - Cyanomitra verticalis.mp3     2  OK
# Extracting  data/add_audio/add_data_3/gnhsun1/XC739636 - Green-headed Sunbird - Cyanomitra verticalis.mp3     2  OK
# Extracting  data/add_audio/add_data_3/gnhsun1/XC774979 - Green-headed Sunbird - Cyanomitra verticalis viridisplendens.wav     2  OK
# Extracting  data/add_audio/add_data_3/gnhsun1/XC791505 - Green-headed Sunbird - Cyanomitra verticalis.mp3     2  OK
# Creating    data/add_audio/add_data_3/gobsta5                         OK
# Extracting  data/add_audio/add_data_3/gobsta5/XC794886 - Golden-breasted Starling - Lamprotornis regius.mp3     2  OK
# Creating    data/add_audio/add_data_3/godwea1                         OK
# Extracting  data/add_audio/add_data_3/godwea1/XC33815 - Golden-backed Weaver - Ploceus jacksoni.mp3     2  OK
# Extracting  data/add_audio/add_data_3/godwea1/XC430203 - Golden-backed Weaver - Ploceus jacksoni.mp3     2  OK
# Extracting  data/add_audio/add_data_3/godwea1/XC449634 - Golden-backed Weaver - Ploceus jacksoni.mp3     2  OK
# Extracting  data/add_audio/add_data_3/godwea1/XC469202 - Golden-backed Weaver - Ploceus jacksoni.mp3     2  OK
# Extracting  data/add_audio/add_data_3/godwea1/XC510339 - Golden-backed Weaver - Ploceus jacksoni.mp3     2  OK
# Extracting  data/add_audio/add_data_3/godwea1/XC510340 - Golden-backed Weaver - Ploceus jacksoni.mp3     2  OK
# Extracting  data/add_audio/add_data_3/godwea1/XC764723 - Golden-backed Weaver - Ploceus jacksoni.mp3     2  OK
# Extracting  data/add_audio/add_data_3/godwea1/XC787554 - Golden-backed Weaver - Ploceus jacksoni.mp3     2  OK
# Extracting  data/add_audio/add_data_3/godwea1/XC93951 - Golden-backed Weaver - Ploceus jacksoni.mp3     2  OK
# Creating    data/add_audio/add_data_3/golher1                         OK
# Extracting  data/add_audio/add_data_3/golher1/golher_1_1.mp3             2  OK
# Extracting  data/add_audio/add_data_3/golher1/golher_1_2.mp3             2  OK
# Extracting  data/add_audio/add_data_3/golher1/golher_1_3.mp3             2  OK
# Extracting  data/add_audio/add_data_3/golher1/golher_1_4.mp3             2  OK
# Creating    data/add_audio/add_data_3/grccra1                         OK
# Extracting  data/add_audio/add_data_3/grccra1/XC251841 - Grey Crowned Crane - Balearica regulorum.mp3     2  OK
# Extracting  data/add_audio/add_data_3/grccra1/XC279856 - Grey Crowned Crane - Balearica regulorum.mp3     2  OK
# Extracting  data/add_audio/add_data_3/grccra1/XC292786 - Grey Crowned Crane - Balearica regulorum regulorum.mp3     2  OK
# Extracting  data/add_audio/add_data_3/grccra1/XC490796 - Grey Crowned Crane - Balearica regulorum.mp3     2  OK
# Extracting  data/add_audio/add_data_3/grccra1/XC509906 - Grey Crowned Crane - Balearica regulorum.mp3     2  OK
# Extracting  data/add_audio/add_data_3/grccra1/XC517503 - Grey Crowned Crane - Balearica regulorum regulorum.mp3     2  OK
# Extracting  data/add_audio/add_data_3/grccra1/XC62293 - Grey Crowned Crane - Balearica regulorum regulorum.mp3     2  OK
# Extracting  data/add_audio/add_data_3/grccra1/XC67440 - Grey Crowned Crane - Balearica regulorum.mp3     2  OK
# Extracting  data/add_audio/add_data_3/grccra1/XC724083 - Grey Crowned Crane - Balearica regulorum.mp3     2  OK
# Extracting  data/add_audio/add_data_3/grccra1/XC739420 - Grey Crowned Crane - Balearica regulorum.mp3     2  OK
# Extracting  data/add_audio/add_data_3/grccra1/XC739421 - Grey Crowned Crane - Balearica regulorum.mp3     2  OK
# Extracting  data/add_audio/add_data_3/grccra1/XC739422 - Grey Crowned Crane - Balearica regulorum.mp3     2  OK
# Extracting  data/add_audio/add_data_3/grccra1/XC739423 - Grey Crowned Crane - Balearica regulorum.mp3     2  OK
# Extracting  data/add_audio/add_data_3/grccra1/XC739424 - Grey Crowned Crane - Balearica regulorum.mp3     2  OK
# Extracting  data/add_audio/add_data_3/grccra1/XC96575 - Grey Crowned Crane - Balearica regulorum.mp3     2  OK
# Creating    data/add_audio/add_data_3/gybfis1                         OK
# Extracting  data/add_audio/add_data_3/gybfis1/XC300414 - Grey-backed Fiscal - Lanius excubitoroides.mp3     2  OK
# Extracting  data/add_audio/add_data_3/gybfis1/XC36290 - Grey-backed Fiscal - Lanius excubitoroides excubitoroides.mp3     2  OK
# Extracting  data/add_audio/add_data_3/gybfis1/XC64978 - Grey-backed Fiscal - Lanius excubitoroides excubitoroides.mp3     2  OK
# Extracting  data/add_audio/add_data_3/gybfis1/XC739772 - Grey-backed Fiscal - Lanius excubitoroides.mp3     2  OK
# Extracting  data/add_audio/add_data_3/gybfis1/XC739773 - Grey-backed Fiscal - Lanius excubitoroides.mp3     2  OK
# Extracting  data/add_audio/add_data_3/gybfis1/XC772440 - Grey-backed Fiscal - Lanius excubitoroides.mp3     2  OK
# Creating    data/add_audio/add_data_3/gytbar1                         OK
# Extracting  data/add_audio/add_data_3/gytbar1/XC451782 - Grey-throated Barbet - Gymnobucco bonapartei cinereiceps.mp3     2  OK
# Extracting  data/add_audio/add_data_3/gytbar1/XC451955 - Grey-throated Barbet - Gymnobucco bonapartei cinereiceps.mp3     2  OK
# Extracting  data/add_audio/add_data_3/gytbar1/XC739696 - Grey-throated Barbet - Gymnobucco bonapartei.mp3     2  OK
# Creating    data/add_audio/add_data_3/hartur1                         OK
# Extracting  data/add_audio/add_data_3/hartur1/XC154732 - Hartlaub's Turaco - Tauraco hartlaubi.mp3     2  OK
# Extracting  data/add_audio/add_data_3/hartur1/XC154733 - Hartlaub's Turaco - Tauraco hartlaubi.mp3     2  OK
# Extracting  data/add_audio/add_data_3/hartur1/XC429854 - Hartlaub's Turaco - Tauraco hartlaubi.mp3     2  OK
# Extracting  data/add_audio/add_data_3/hartur1/XC429855 - Hartlaub's Turaco - Tauraco hartlaubi.mp3     3  OK
# Extracting  data/add_audio/add_data_3/hartur1/XC429856 - Hartlaub's Turaco - Tauraco hartlaubi.mp3     3  OK
# Extracting  data/add_audio/add_data_3/hartur1/XC430152 - Hartlaub's Turaco - Tauraco hartlaubi.mp3     3  OK
# Extracting  data/add_audio/add_data_3/hartur1/XC430153 - Hartlaub's Turaco - Tauraco hartlaubi.mp3     3  OK
# Extracting  data/add_audio/add_data_3/hartur1/XC450394 - Hartlaub's Turaco - Tauraco hartlaubi.mp3     3  OK
# Extracting  data/add_audio/add_data_3/hartur1/XC450395 - Hartlaub's Turaco - Tauraco hartlaubi.mp3     3  OK
# Extracting  data/add_audio/add_data_3/hartur1/XC455437 - Hartlaub's Turaco - Tauraco hartlaubi.mp3     3  OK
# Extracting  data/add_audio/add_data_3/hartur1/XC455438 - Hartlaub's Turaco - Tauraco hartlaubi.mp3     3  OK
# Extracting  data/add_audio/add_data_3/hartur1/XC510423 - Hartlaub's Turaco - Tauraco hartlaubi.mp3     3  OK
# Extracting  data/add_audio/add_data_3/hartur1/XC510424 - Hartlaub's Turaco - Tauraco hartlaubi.mp3     3  OK
# Extracting  data/add_audio/add_data_3/hartur1/XC510425 - Hartlaub's Turaco - Tauraco hartlaubi.mp3     3  OK
# Extracting  data/add_audio/add_data_3/hartur1/XC510426 - Hartlaub's Turaco - Tauraco hartlaubi.mp3     3  OK
# Extracting  data/add_audio/add_data_3/hartur1/XC59937 - Hartlaub's Turaco - Tauraco hartlaubi.mp3     3  OK
# Extracting  data/add_audio/add_data_3/hartur1/XC763268 - Hartlaub's Turaco - Tauraco hartlaubi.mp3     3  OK
# Extracting  data/add_audio/add_data_3/hartur1/XC780196 - Hartlaub's Turaco - Tauraco hartlaubi.mp3     3  OK
# Extracting  data/add_audio/add_data_3/hartur1/XC780197 - Hartlaub's Turaco - Tauraco hartlaubi.mp3     3  OK
# Creating    data/add_audio/add_data_3/hipbab1                         OK
# Extracting  data/add_audio/add_data_3/hipbab1/XC775917 - Hinde's Babbler - Turdoides hindei.mp3     3  OK
# Extracting  data/add_audio/add_data_3/hipbab1/XC775919 - Hinde's Babbler - Turdoides hindei.mp3     3  OK
# Creating    data/add_audio/add_data_3/huncis1                         OK
# Extracting  data/add_audio/add_data_3/huncis1/XC449338 - Hunter's Cisticola - Cisticola hunteri.mp3     3  OK
# Extracting  data/add_audio/add_data_3/huncis1/XC449339 - Hunter's Cisticola - Cisticola hunteri.mp3     3  OK
# Extracting  data/add_audio/add_data_3/huncis1/XC449340 - Hunter's Cisticola - Cisticola hunteri.mp3     3  OK
# Extracting  data/add_audio/add_data_3/huncis1/XC449342 - Hunter's Cisticola - Cisticola hunteri.mp3     3  OK
# Extracting  data/add_audio/add_data_3/huncis1/XC449343 - Hunter's Cisticola - Cisticola hunteri.mp3     3  OK
# Extracting  data/add_audio/add_data_3/huncis1/XC449344 - Hunter's Cisticola - Cisticola hunteri.mp3     3  OK
# Extracting  data/add_audio/add_data_3/huncis1/XC449346 - Hunter's Cisticola - Cisticola hunteri.mp3     3  OK
# Extracting  data/add_audio/add_data_3/huncis1/XC449347 - Hunter's Cisticola - Cisticola hunteri.mp3     3  OK
# Extracting  data/add_audio/add_data_3/huncis1/XC449349 - Hunter's Cisticola - Cisticola hunteri.mp3     3  OK
# Extracting  data/add_audio/add_data_3/huncis1/XC450352 - Hunter's Cisticola - Cisticola hunteri.mp3     3  OK
# Extracting  data/add_audio/add_data_3/huncis1/XC450353 - Hunter's Cisticola - Cisticola hunteri.mp3     3  OK
# Extracting  data/add_audio/add_data_3/huncis1/XC450354 - Hunter's Cisticola - Cisticola hunteri.mp3     3  OK
# Extracting  data/add_audio/add_data_3/huncis1/XC455653 - Hunter's Cisticola - Cisticola hunteri.mp3     3  OK
# Extracting  data/add_audio/add_data_3/huncis1/XC648331 - Hunter's Cisticola - Cisticola hunteri.mp3     3  OK
# Extracting  data/add_audio/add_data_3/huncis1/XC772807 - Hunter's Cisticola - Cisticola hunteri.mp3     3  OK
# Extracting  data/add_audio/add_data_3/huncis1/XC774251 - Hunter's Cisticola - Cisticola hunteri.wav     3  OK
# Extracting  data/add_audio/add_data_3/huncis1/XC774252 - Hunter's Cisticola - Cisticola hunteri.wav     3  OK
# Extracting  data/add_audio/add_data_3/huncis1/XC798990 - Hunter's Cisticola - Cisticola hunteri.mp3     3  OK
# Extracting  data/add_audio/add_data_3/huncis1/XC800902 - Hunter's Cisticola - Cisticola hunteri.mp3     3  OK
# Extracting  data/add_audio/add_data_3/huncis1/XC96691 - Hunter's Cisticola - Cisticola hunteri.mp3     3  OK
# Extracting  data/add_audio/add_data_3/huncis1/XC96692 - Hunter's Cisticola - Cisticola hunteri.mp3     3  OK
# Creating    data/add_audio/add_data_3/hunsun2                         OK
# Extracting  data/add_audio/add_data_3/hunsun2/XC300095 - Hunter's Sunbird - Chalcomitra hunteri.mp3     3  OK
# Extracting  data/add_audio/add_data_3/hunsun2/XC510003 - Hunter's Sunbird - Chalcomitra hunteri.mp3     3  OK
# Extracting  data/add_audio/add_data_3/hunsun2/XC773812 - Hunter's Sunbird - Chalcomitra hunteri.mp3     3  OK
# Extracting  data/add_audio/add_data_3/hunsun2/XC773813 - Hunter's Sunbird - Chalcomitra hunteri.mp3     3  OK
# Extracting  data/add_audio/add_data_3/hunsun2/XC776130 - Hunter's Sunbird - Chalcomitra hunteri.mp3     3  OK
# Creating    data/add_audio/add_data_3/joygre1                         OK
# Extracting  data/add_audio/add_data_3/joygre1/XC101186 - Joyful Greenbul - Chlorocichla laetissima.mp3     3  OK
# Extracting  data/add_audio/add_data_3/joygre1/XC101187 - Joyful Greenbul - Chlorocichla laetissima.mp3     3  OK
# Extracting  data/add_audio/add_data_3/joygre1/XC452012 - Joyful Greenbul - Chlorocichla laetissima laetissima.mp3     3  OK
# Extracting  data/add_audio/add_data_3/joygre1/XC62964 - Joyful Greenbul - Chlorocichla laetissima.mp3     3  OK
# Extracting  data/add_audio/add_data_3/joygre1/XC773771 - Joyful Greenbul - Chlorocichla laetissima laetissima.wav     3  OK
# Extracting  data/add_audio/add_data_3/joygre1/XC97934 - Joyful Greenbul - Chlorocichla laetissima laetissima.mp3     3  OK
# Creating    data/add_audio/add_data_3/kvbsun1                         OK
# Extracting  data/add_audio/add_data_3/kvbsun1/XC299951 - Eastern Violet-backed Sunbird - Anthreptes orientalis.mp3     3  OK
# Extracting  data/add_audio/add_data_3/kvbsun1/XC299952 - Eastern Violet-backed Sunbird - Anthreptes orientalis.mp3     3  OK
# Extracting  data/add_audio/add_data_3/kvbsun1/XC305977 - Eastern Violet-backed Sunbird - Anthreptes orientalis.mp3     3  OK
# Extracting  data/add_audio/add_data_3/kvbsun1/XC451452 - Eastern Violet-backed Sunbird - Anthreptes orientalis.mp3     3  OK
# Extracting  data/add_audio/add_data_3/kvbsun1/XC451742 - Eastern Violet-backed Sunbird - Anthreptes orientalis.mp3     3  OK
# Extracting  data/add_audio/add_data_3/kvbsun1/XC468993 - Eastern Violet-backed Sunbird - Anthreptes orientalis.mp3     3  OK
# Extracting  data/add_audio/add_data_3/kvbsun1/XC509863 - Eastern Violet-backed Sunbird - Anthreptes orientalis.mp3     3  OK
# Extracting  data/add_audio/add_data_3/kvbsun1/XC509865 - Eastern Violet-backed Sunbird - Anthreptes orientalis.mp3     3  OK
# Extracting  data/add_audio/add_data_3/kvbsun1/XC509866 - Eastern Violet-backed Sunbird - Anthreptes orientalis.mp3     3  OK
# Extracting  data/add_audio/add_data_3/kvbsun1/XC57556 - Eastern Violet-backed Sunbird - Anthreptes orientalis.mp3     3  OK
# Creating    data/add_audio/add_data_3/lesmaw1                         OK
# Extracting  data/add_audio/add_data_3/lesmaw1/XC107542 - Lesser Masked Weaver - Ploceus intermedius.mp3     3  OK
# Extracting  data/add_audio/add_data_3/lesmaw1/XC268880 - Lesser Masked Weaver - Ploceus intermedius intermedius.mp3     3  OK
# Extracting  data/add_audio/add_data_3/lesmaw1/XC280561 - Lesser Masked Weaver - Ploceus intermedius.mp3     3  OK
# Extracting  data/add_audio/add_data_3/lesmaw1/XC280563 - Lesser Masked Weaver - Ploceus intermedius.mp3     3  OK
# Extracting  data/add_audio/add_data_3/lesmaw1/XC280564 - Lesser Masked Weaver - Ploceus intermedius.mp3     3  OK
# Extracting  data/add_audio/add_data_3/lesmaw1/XC280566 - Lesser Masked Weaver - Ploceus intermedius.mp3     3  OK
# Extracting  data/add_audio/add_data_3/lesmaw1/XC280571 - Lesser Masked Weaver - Ploceus intermedius.mp3     3  OK
# Extracting  data/add_audio/add_data_3/lesmaw1/XC365299 - Lesser Masked Weaver - Ploceus intermedius cabanisii.mp3     3  OK
# Extracting  data/add_audio/add_data_3/lesmaw1/XC365300 - Lesser Masked Weaver - Ploceus intermedius cabanisii.mp3     3  OK
# Extracting  data/add_audio/add_data_3/lesmaw1/XC371355 - Lesser Masked Weaver - Ploceus intermedius.mp3     3  OK
# Extracting  data/add_audio/add_data_3/lesmaw1/XC429661 - Lesser Masked Weaver - Ploceus intermedius intermedius.mp3     3  OK
# Extracting  data/add_audio/add_data_3/lesmaw1/XC430236 - Lesser Masked Weaver - Ploceus intermedius intermedius.mp3     3  OK
# Extracting  data/add_audio/add_data_3/lesmaw1/XC430237 - Lesser Masked Weaver - Ploceus intermedius intermedius.mp3     4  OK
# Extracting  data/add_audio/add_data_3/lesmaw1/XC430238 - Lesser Masked Weaver - Ploceus intermedius intermedius.mp3     4  OK
# Extracting  data/add_audio/add_data_3/lesmaw1/XC430239 - Lesser Masked Weaver - Ploceus intermedius intermedius.mp3     4  OK
# Extracting  data/add_audio/add_data_3/lesmaw1/XC449631 - Lesser Masked Weaver - Ploceus intermedius intermedius.mp3     4  OK
# Extracting  data/add_audio/add_data_3/lesmaw1/XC449633 - Lesser Masked Weaver - Ploceus intermedius intermedius.mp3     4  OK
# Extracting  data/add_audio/add_data_3/lesmaw1/XC449644 - Lesser Masked Weaver - Ploceus intermedius.mp3     4  OK
# Extracting  data/add_audio/add_data_3/lesmaw1/XC449646 - Lesser Masked Weaver - Ploceus intermedius.mp3     4  OK
# Extracting  data/add_audio/add_data_3/lesmaw1/XC449647 - Lesser Masked Weaver - Ploceus intermedius intermedius.mp3     4  OK
# Extracting  data/add_audio/add_data_3/lesmaw1/XC451575 - Lesser Masked Weaver - Ploceus intermedius intermedius.mp3     4  OK
# Extracting  data/add_audio/add_data_3/lesmaw1/XC62371 - Lesser Masked Weaver - Ploceus intermedius cabanisii.mp3     4  OK
# Extracting  data/add_audio/add_data_3/lesmaw1/XC739924 - Lesser Masked Weaver - Ploceus intermedius.mp3     4  OK
# Extracting  data/add_audio/add_data_3/lesmaw1/XC739925 - Lesser Masked Weaver - Ploceus intermedius.mp3     4  OK
# Extracting  data/add_audio/add_data_3/lesmaw1/XC93956 - Lesser Masked Weaver - Ploceus intermedius.mp3     4  OK
# Creating    data/add_audio/add_data_3/litwea1                         OK
# Extracting  data/add_audio/add_data_3/litwea1/XC268890 - Little Weaver - Ploceus luteolus luteolus.mp3     4  OK
# Extracting  data/add_audio/add_data_3/litwea1/XC268891 - Little Weaver - Ploceus luteolus luteolus.mp3     4  OK
# Extracting  data/add_audio/add_data_3/litwea1/XC451576 - Little Weaver - Ploceus luteolus kavirondensis.mp3     4  OK
# Extracting  data/add_audio/add_data_3/litwea1/XC719410 - Little Weaver - Ploceus luteolus.mp3     4  OK
# Creating    data/add_audio/add_data_3/loceag1                         OK
# Extracting  data/add_audio/add_data_3/loceag1/XC268790 - Long-crested Eagle - Lophaetus occipitalis.mp3     4  OK
# Extracting  data/add_audio/add_data_3/loceag1/XC268791 - Long-crested Eagle - Lophaetus occipitalis.mp3     4  OK
# Extracting  data/add_audio/add_data_3/loceag1/XC268792 - Long-crested Eagle - Lophaetus occipitalis.mp3     4  OK
# Extracting  data/add_audio/add_data_3/loceag1/XC280406 - Long-crested Eagle - Lophaetus occipitalis.mp3     4  OK
# Extracting  data/add_audio/add_data_3/loceag1/XC39306 - Long-crested Eagle - Lophaetus occipitalis.mp3     4  OK
# Extracting  data/add_audio/add_data_3/loceag1/XC48370 - Long-crested Eagle - Lophaetus occipitalis.mp3     4  OK
# Extracting  data/add_audio/add_data_3/loceag1/XC510226 - Long-crested Eagle - Lophaetus occipitalis.mp3     4  OK
# Extracting  data/add_audio/add_data_3/loceag1/XC739780 - Long-crested Eagle - Lophaetus occipitalis.mp3     4  OK
# Extracting  data/add_audio/add_data_3/loceag1/XC774255 - Long-crested Eagle - Lophaetus occipitalis.wav     4  OK
# ...
# Extracting  data/base_audio/yertin1/XC634072.ogg                        99  OK
# Extracting  data/base_audio/yertin1/XC634073.ogg                        99  OK
# Extracting  data/base_audio/yertin1/XC634123.ogg                        99  OK
# Extracting  data/base_audio/yertin1/XC634144.ogg                        99  OK
# Extracting  data/base_audio/yertin1/XC634148.ogg                        99  OK
# Extracting  data/base_audio/yertin1/XC634151.ogg                        99  OK
# Extracting  data/base_audio/yertin1/XC634152.ogg                        99  OK
# Extracting  data/base_audio/yertin1/XC634155.ogg                        99  OK
# Extracting  data/base_audio/yertin1/XC634157.ogg                        99  OK
# Extracting  data/base_audio/yertin1/XC634159.ogg                        99  OK
# Extracting  data/base_audio/yertin1/XC634191.ogg                        99  OK
# Extracting  data/base_audio/yertin1/XC634196.ogg                        99  OK
# Extracting  data/base_audio/yertin1/XC634198.ogg                        99  OK
# Extracting  data/base_audio/yertin1/XC634199.ogg                        99  OK
# Extracting  data/base_audio/yertin1/XC675469.ogg                        99  OK
# Extracting  data/base_audio/yertin1/XC753425.ogg                        99  OK
# Creating    data/base_audio/yesbar1                                   OK
# Extracting  data/base_audio/yesbar1/XC138932.ogg                        99  OK
# Extracting  data/base_audio/yesbar1/XC138933.ogg                        99  OK
# Extracting  data/base_audio/yesbar1/XC169720.ogg                        99  OK
# Extracting  data/base_audio/yesbar1/XC233336.ogg                        99  OK
# Extracting  data/base_audio/yesbar1/XC245978.ogg                        99  OK
# Extracting  data/base_audio/yesbar1/XC246010.ogg                        99  OK
# Extracting  data/base_audio/yesbar1/XC263445.ogg                        99  OK
# Extracting  data/base_audio/yesbar1/XC263449.ogg                        99  OK
# Extracting  data/base_audio/yesbar1/XC263478.ogg                        99  OK
# Extracting  data/base_audio/yesbar1/XC264914.ogg                        99  OK
# Extracting  data/base_audio/yesbar1/XC267371.ogg                        99  OK
# Extracting  data/base_audio/yesbar1/XC281973.ogg                        99  OK
# Extracting  data/base_audio/yesbar1/XC353565.ogg                        99  OK
# Extracting  data/base_audio/yesbar1/XC360423.ogg                        99  OK
# Extracting  data/base_audio/yesbar1/XC395749.ogg                        99  OK
# Extracting  data/base_audio/yesbar1/XC397057.ogg                        99  OK
# Extracting  data/base_audio/yesbar1/XC400182.ogg                        99  OK
# Extracting  data/base_audio/yesbar1/XC400183.ogg                        99  OK
# Extracting  data/base_audio/yesbar1/XC400460.ogg                        99  OK
# Extracting  data/base_audio/yesbar1/XC419616.ogg                        99  OK
# Extracting  data/base_audio/yesbar1/XC468004.ogg                        99  OK
# Extracting  data/base_audio/yesbar1/XC468005.ogg                        99  OK
# Extracting  data/base_audio/yesbar1/XC468006.ogg                        99  OK
# Extracting  data/base_audio/yesbar1/XC468007.ogg                        99  OK
# Extracting  data/base_audio/yesbar1/XC482165.ogg                        99  OK
# Extracting  data/base_audio/yesbar1/XC482167.ogg                        99  OK
# Extracting  data/base_audio/yesbar1/XC503400.ogg                        99  OK
# Extracting  data/base_audio/yesbar1/XC503401.ogg                        99  OK
# Extracting  data/base_audio/yesbar1/XC700474.ogg                        99  OK
# Creating    data/base_audio/yespet1                                   OK
# Extracting  data/base_audio/yespet1/XC208439.ogg                        99  OK
# Extracting  data/base_audio/yespet1/XC294872.ogg                        99  OK
# Extracting  data/base_audio/yespet1/XC363499.ogg                        99  OK
# Extracting  data/base_audio/yespet1/XC364377.ogg                        99  OK
# Extracting  data/base_audio/yespet1/XC392980.ogg                        99  OK
# Extracting  data/base_audio/yespet1/XC393627.ogg                        99  OK
# Extracting  data/base_audio/yespet1/XC602617.ogg                        99  OK
# Extracting  data/base_audio/yespet1/XC602618.ogg                        99  OK
# Extracting  data/base_audio/yespet1/XC602619.ogg                        99  OK
# Extracting  data/base_audio/yespet1/XC605080.ogg                        99  OK
# Extracting  data/base_audio/yespet1/XC610331.ogg                        99  OK
# Extracting  data/base_audio/yespet1/XC627250.ogg                        99  OK
# Extracting  data/base_audio/yespet1/XC630279.ogg                        99  OK
# Extracting  data/base_audio/yespet1/XC692101.ogg                        99  OK
# Extracting  data/base_audio/yespet1/XC697686.ogg                        99  OK
# Creating    data/base_audio/yetgre1                                   OK
# Extracting  data/base_audio/yetgre1/XC247367.ogg                        99  OK
# Extracting  data/base_audio/yetgre1/XC247369.ogg                        99  OK
# Extracting  data/base_audio/yetgre1/XC282051.ogg                        99  OK
# Extracting  data/base_audio/yetgre1/XC289493.ogg                        99  OK
# Extracting  data/base_audio/yetgre1/XC338717.ogg                        99  OK
# Extracting  data/base_audio/yetgre1/XC339708.ogg                        99  OK
# Extracting  data/base_audio/yetgre1/XC344194.ogg                        99  OK
# Extracting  data/base_audio/yetgre1/XC344251.ogg                        99  OK
# Extracting  data/base_audio/yetgre1/XC346069.ogg                        99  OK
# Extracting  data/base_audio/yetgre1/XC349660.ogg                        99  OK
# Extracting  data/base_audio/yetgre1/XC349661.ogg                        99  OK
# Extracting  data/base_audio/yetgre1/XC370962.ogg                        99  OK
# Extracting  data/base_audio/yetgre1/XC373426.ogg                        99  OK
# Extracting  data/base_audio/yetgre1/XC403259.ogg                        99  OK
# Extracting  data/base_audio/yetgre1/XC403543.ogg                        99  OK
# Extracting  data/base_audio/yetgre1/XC405750.ogg                        99  OK
# Extracting  data/base_audio/yetgre1/XC475334.ogg                        99  OK
# Extracting  data/base_audio/yetgre1/XC498853.ogg                        99  OK
# Extracting  data/base_audio/yetgre1/XC498854.ogg                        99  OK
# Extracting  data/base_audio/yetgre1/XC530126.ogg                        99  OK
# Extracting  data/base_audio/yetgre1/XC530241.ogg                        99  OK
# Extracting  data/base_audio/yetgre1/XC530242.ogg                        99  OK
# Extracting  data/base_audio/yetgre1/XC574557.ogg                        99  OK
# Extracting  data/base_audio/yetgre1/XC574558.ogg                        99  OK
# Extracting  data/base_audio/yetgre1/XC574559.ogg                        99  OK
# Extracting  data/base_audio/yetgre1/XC667564.ogg                        99  OK
# Extracting  data/base_audio/yetgre1/XC716763.ogg                        99  OK
# Creating    data/base_audio/yewgre1                                   OK
# Extracting  data/base_audio/yewgre1/XC113255.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC113256.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC113435.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC120611.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC122417.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC126589.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC126612.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC131906.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC144141.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC157118.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC163357.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC164153.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC18465.ogg                         99  OK
# Extracting  data/base_audio/yewgre1/XC201221.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC205780.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC209729.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC233084.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC233785.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC234851.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC234853.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC234854.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC235869.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC235870.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC235944.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC235945.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC235946.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC235947.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC236324.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC236845.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC236846.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC236847.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC236857.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC236865.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC236870.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC236966.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC237453.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC237454.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC239970.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC240502.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC240503.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC246126.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC246128.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC263443.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC265799.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC266006.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC284889.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC284895.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC287948.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC293991.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC298398.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC301453.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC301602.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC301603.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC302981.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC302982.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC309411.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC318287.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC325878.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC336100.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC343780.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC344996.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC347627.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC365413.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC371862.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC374341.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC396379.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC397065.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC397066.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC397164.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC397165.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC397563.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC397731.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC397732.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC399131.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC399734.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC400185.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC400186.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC400188.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC401866.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC401867.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC401892.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC429112.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC429122.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC432176.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC470576.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC476762.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC478540.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC479059.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC479061.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC48477.ogg                         99  OK
# Extracting  data/base_audio/yewgre1/XC487128.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC505815.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC506518.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC513865.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC514644.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC530236.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC537944.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC617114.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC641613.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC675466.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC675467.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC700545.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC700615.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC703472.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC703485.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC704433.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC752974.ogg                        99  OK
# Extracting  data/base_audio/yewgre1/XC753190.ogg                        99  OK
# Extracting  data/train_base.csv                                         99  OK
# All OK

# %%
import sys 
sys.path.append("/kaggle/working/model_compression")
sys.path.append("/kaggle/working/model_compression/scr")

# %%
import os
import yaml
import time
import datetime
import warnings
import sys

from tqdm import tqdm

import torch
import timm
import pandas as pd
import numpy as np
import torch.nn as nn

from box import Box
from torch.utils.data import DataLoader
from loguru import logger

from utils.create_dataset import BirdDataset
from utils.base_utils import set_seed
from utils.metrics import validation_epoch_end

# %%
warnings.filterwarnings("ignore", category=UserWarning)
date_now = datetime.datetime.now().strftime("%d_%B_%Y_%H_%M")

path_save = os.path.join("../experiment", date_now)
if not os.path.exists(path_save):
    os.makedirs(path_save)

    
# Load config with params for training

config = Box()
config.debug= False
config.seed = 1771
config.path_to_files_base= "../data/data"
config.batch_size = 32
config.num_workers= 0
config.optimizer_lr= 0.006
config.optimizer_wd= 0
config.model_name= "tf_efficientnet_b0"
config.metric = "custom"
config.epochs= 15



logger.add(f"{path_save}/info_log{date_now}.log",
           format="<red>{time:YYYY-MM-DD HH:mm:ss}</red>| {message}")


logger.info(f"Folder with experiment- {path_save}")
logger.info("----------params----------")

for param in config:
    logger.info(f"{param}: {str(config[param])}")

# Create device for training and set_seed:
config.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
set_seed(seed=config.seed)

# Read data
df = pd.read_csv("/kaggle/working/model_compression/data/data.csv")
df_train, df_test = (df[df.fold != 3].reset_index(drop=True),
                     df[df.fold == 3].reset_index(drop=True)
                     )
logger.info(f"Size df_train- {df_train.shape[0]}")
logger.info(f"Size df_test- {df_test.shape[0]}")
# Out:
# 2023-10-06 16:53:20.042 | INFO     | __main__:<module>:29 - Folder with experiment- ../experiment/06_October_2023_16_53
# 2023-10-06 16:53:20.044 | INFO     | __main__:<module>:30 - ----------params----------
# 2023-10-06 16:53:20.045 | INFO     | __main__:<module>:33 - debug: False
# 2023-10-06 16:53:20.046 | INFO     | __main__:<module>:33 - seed: 1771
# 2023-10-06 16:53:20.048 | INFO     | __main__:<module>:33 - path_to_files_base: ../data/data
# 2023-10-06 16:53:20.049 | INFO     | __main__:<module>:33 - batch_size: 32
# 2023-10-06 16:53:20.050 | INFO     | __main__:<module>:33 - num_workers: 0
# 2023-10-06 16:53:20.051 | INFO     | __main__:<module>:33 - optimizer_lr: 0.006
# 2023-10-06 16:53:20.052 | INFO     | __main__:<module>:33 - optimizer_wd: 0
# 2023-10-06 16:53:20.053 | INFO     | __main__:<module>:33 - model_name: tf_efficientnet_b0
# 2023-10-06 16:53:20.054 | INFO     | __main__:<module>:33 - metric: custom
# 2023-10-06 16:53:20.055 | INFO     | __main__:<module>:33 - epochs: 15
# 2023-10-06 16:53:20.121 | INFO     | utils.base_utils:set_seed:19 - Set seed: 1771
# 2023-10-06 16:53:20.166 | INFO     | __main__:<module>:44 - Size df_train- 12326
# 2023-10-06 16:53:20.167 | INFO     | __main__:<module>:45 - Size df_test- 3082

# %%
dataset_train = BirdDataset(df=df_train,
                            path_to_folder_with_audio=config.path_to_files_base,
                            tensorflow=True
                            )
dataset_test = BirdDataset(df=df_test,
                           path_to_folder_with_audio=config.path_to_files_base,
                           tensorflow=True
                           )

train_loader = DataLoader(dataset_train,
                          batch_size=config.batch_size,
                          shuffle=True,
                          num_workers=config.num_workers)
valid_loader = DataLoader(dataset_test,
                          batch_size=config.batch_size,
                          num_workers=config.num_workers)

# %%
from tensorflow.keras.layers.experimental import preprocessing
import tensorflow as tf
# Out:
# 2023-10-06 16:53:33.081637: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-06 16:53:33.081712: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-06 16:53:33.117271: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
model = tf.keras.applications.efficientnet.EfficientNetB0(
    weights='imagenet',
    include_top=False,
    input_shape=(626, 256, 3),
    drop_connect_rate=0.4,
)

input_shape = (626, 256, 3)
# Define the pre-processing layers for the input spectrogram
# preprocessing_layers = [
#     preprocessing.Normalization(),
# ]

# Define the spectrogram classification model
model = tf.keras.Sequential([
    tf.keras.Input(shape=input_shape),
    # *preprocessing_layers,
    model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(264, activation='sigmoid')])
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 3s 0us/step

# %%
learning_rate_schedule = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=config.optimizer_lr,
    decay_steps=config.epochs * len(train_loader),  # Устанавливаем decay_steps равным общему числу эпох
    alpha=0.0  # alpha устанавливается в 0.0 для чистой косинусной функции
)

# %%
loss_fn = tf.keras.losses.BinaryCrossentropy()  # Для бинарной классификации
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate_schedule)

# %%
# Получите текущее значение learning rate
current_learning_rate = optimizer.learning_rate.numpy()

# %%
model.compile(optimizer=optimizer, loss=loss_fn, metrics=['accuracy'])

# %%
model = model
metric = validation_epoch_end

# %%
strategy = tf.distribute.OneDeviceStrategy(device="/gpu:0")

# %%
with strategy.scope():
    model = model

# %%
cd ../scr
# Out:
# /kaggle/working/model_compression/scr

# %%
logger.info(f"Starting train. Model - {config.model_name}")
for epoch_i in range(1, config.epochs + 1):
    if config.debug:
        k = 1
    start = time.time()
    logger.info(f'---------------------epoch:{epoch_i}/{config.epochs}---------------------')

    # loss
    avg_train_loss = 0
    avg_val_loss = 0
    predicted_labels_list = None
    true_labels_list = None

    ############## Train #############
    train_pbar = tqdm(train_loader, desc="Training")
    for batch in train_pbar:
        X_batch = batch[0]
        y_batch = batch[1]

        #convert to tf 
        X_batch = tf.convert_to_tensor(X_batch.numpy(), dtype=tf.float32)
        y_batch = tf.convert_to_tensor(y_batch.numpy(), dtype=tf.float32)

        
        with tf.GradientTape() as tape:
            logits = model(X_batch, training=True)
            loss_value = loss_fn(y_batch, logits)

        grads = tape.gradient(loss_value, model.trainable_variables)
        optimizer.apply_gradients(zip(grads, model.trainable_variables))
        avg_train_loss += loss_value.numpy()

        if config.debug:
            k += 1
            if k > 3: break

    valid_pbar = tqdm(valid_loader, desc="Validation")
    for batch in (valid_pbar):
        X_batch = batch[0]
        y_b = batch[1]

        #convert to tf 
        X_batch = tf.convert_to_tensor(X_batch.numpy(), dtype=tf.float32)
        y_batch = tf.convert_to_tensor(y_b.numpy(), dtype=tf.float32)

        logits = model(X_batch, training=True)
        loss_value = loss_fn(y_batch, logits)
        if predicted_labels_list is None:
                predicted_labels_list = logits
                true_labels_list = y_b
        else:
            predicted_labels_list = np.concatenate([predicted_labels_list, logits.numpy()], axis=0)
            true_labels_list = np.concatenate([true_labels_list, y_b], axis=0)
            
        if config.debug:
            k += 1
            if k > 6:  break


    all_predicted_labels = np.vstack(predicted_labels_list)
    all_true_labels = np.vstack(true_labels_list)
    all_true_labels = np.squeeze(all_true_labels)
    mask = (all_true_labels > 0) & (all_true_labels < 1)
    all_true_labels[mask] = 0
    avg_metric = metric(all_true_labels, all_predicted_labels)

    logger.info(f'epoch: {epoch_i}')

    logger.info("loss_train: %0.4f| loss_valid: %0.4f|" % (avg_train_loss, avg_val_loss))
    for m in avg_metric:
        logger.info(f"metric {m} : {avg_metric[m]:.<5g}")

    elapsed_time = time.time() - start
/it]Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# Validation: 100%|██████████| 97/97 [05:33<00:00,  3.44s/it]
# 2023-10-06 23:56:36.266 | INFO     | __main__:<module>:67 - epoch: 13
# 2023-10-06 23:56:36.268 | INFO     | __main__:<module>:69 - loss_train: 2.7887| loss_valid: 0.0000|
# 2023-10-06 23:56:36.269 | INFO     | __main__:<module>:71 - metric val_RMAP : 0.325254
# 2023-10-06 23:56:36.270 | INFO     | __main__:<module>:77 - Elapsed time: 00:31:49
# 2023-10-06 23:57:02.481 | INFO     | __main__:<module>:6 - ---------------------epoch:14/15---------------------
# Training:  21%|██        | 82/386 [05:44<21:01,  4.15s/it]Note: Illegal Audio-MPEG-Header 0x61290b00 at offset 547443.
# Note: Trying to resync...
# Note: Hit end of (available) data during resync.
# Training:  39%|███▊      | 149/386 [10:23<16:42,  4.23s/it]Note: Illegal Audio-MPEG-Header 0x6f70706f at offset 615616.
# Note: Trying to resync...
# Note: Hit end of (available) data during resync.
# Training:  58%|█████▊    | 222/386 [15:23<11:34,  4.23s/it]Note: Illegal Audio-MPEG-Header 0x6f70706f at offset 973696.
# Note: Trying to resync...
# Note: Hit end of (available) data during resync.
# Training:  81%|████████  | 313/386 [21:50<05:06,  4.20s/it]Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# Training:  97%|█████████▋| 375/386 [26:13<00:45,  4.16s/it]Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# Training: 100%|██████████| 386/386 [26:56<00:00,  4.19s/it]
# Validation:   1%|          | 1/97 [00:05<08:09,  5.10s/it]Note: Illegal Audio-MPEG-Header 0x656e6129 at offset 97301.
# Note: Trying to resync...
# Note: Hit end of (available) data during resync.
# Validation:   3%|▎         | 3/97 [00:15<08:12,  5.24s/it]Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# Validation: 100%|██████████| 97/97 [05:39<00:00,  3.50s/it]
# 2023-10-07 00:29:38.880 | INFO     | __main__:<module>:67 - epoch: 14
# 2023-10-07 00:29:38.881 | INFO     | __main__:<module>:69 - loss_train: 2.6222| loss_valid: 0.0000|
# 2023-10-07 00:29:38.883 | INFO     | __main__:<module>:71 - metric val_RMAP : 0.32088
# 2023-10-07 00:29:38.884 | INFO     | __main__:<module>:77 - Elapsed time: 00:32:36
# 2023-10-07 00:30:05.554 | INFO     | __main__:<module>:6 - ---------------------epoch:15/15---------------------
# Training:  21%|██        | 81/386 [05:36<20:47,  4.09s/it]Note: Illegal Audio-MPEG-Header 0x6f70706f at offset 973696.
# Note: Trying to resync...
# Note: Hit end of (available) data during resync.
# Training:  42%|████▏     | 164/386 [11:21<14:49,  4.01s/it]Note: Illegal Audio-MPEG-Header 0x6f70706f at offset 615616.
# Note: Trying to resync...
# Note: Hit end of (available) data during resync.
# Training:  47%|████▋     | 181/386 [12:34<14:36,  4.27s/it]Note: Illegal Audio-MPEG-Header 0x61290b00 at offset 547443.
# Note: Trying to resync...
# Note: Hit end of (available) data during resync.
# Training:  54%|█████▎    | 207/386 [14:23<12:25,  4.17s/it]Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# Training:  97%|█████████▋| 376/386 [26:15<00:42,  4.23s/it]Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# Training: 100%|██████████| 386/386 [26:54<00:00,  4.18s/it]
# Validation:   1%|          | 1/97 [00:04<07:59,  4.99s/it]Note: Illegal Audio-MPEG-Header 0x656e6129 at offset 97301.
# Note: Trying to resync...
# Note: Hit end of (available) data during resync.
# Validation:   3%|▎         | 3/97 [00:15<08:22,  5.35s/it]Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# Validation: 100%|██████████| 97/97 [05:43<00:00,  3.54s/it]
# 2023-10-07 01:02:43.509 | INFO     | __main__:<module>:67 - epoch: 15
# 2023-10-07 01:02:43.511 | INFO     | __main__:<module>:69 - loss_train: 2.5007| loss_valid: 0.0000|
# 2023-10-07 01:02:43.512 | INFO     | __main__:<module>:71 - metric val_RMAP : 0.324915
# 2023-10-07 01:02:43.513 | INFO     | __main__:<module>:77 - Elapsed time: 00:32:37

# %%
import zipfile
import os

folder_path = '/kaggle/working/model_compression/experiment/06_October_2023_16_53/model_tf_efficientnet_b0_ep_15_folder'
archive_name = 'tf_model.zip'

# Create the archive
with zipfile.ZipFile(archive_name, 'w', zipfile.ZIP_DEFLATED) as archive:
    for root, directories, files in os.walk(folder_path):
        for file in files:
            file_path = os.path.join(root, file)
            relative_path = os.path.relpath(file_path, folder_path)
            archive.write(file_path, relative_path)

print(f'Archive {archive_name} created successfully.')
# Out:
# Archive tf_model.zip created successfully.

# %%
pwd
# Out:
# '/kaggle/working/model_compression/scr'
